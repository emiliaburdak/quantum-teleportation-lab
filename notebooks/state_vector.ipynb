# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

qc = QuantumCircuit(1)
qc.h(0)

state = Statevector.from_instruction(qc)
state
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
state.probabilities_dict()
# Out:
# {np.str_('0'): np.float64(0.4999999999999999),
#  np.str_('1'): np.float64(0.4999999999999999)}

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

def sv(qc):
    return Statevector.from_instruction(qc)

qc1 = QuantumCircuit(1)
qc1.h(0)
print("Po H:", sv(qc1).data)

qc2 = QuantumCircuit(1)
qc2.h(0)
qc2.z(0)
print("Po H, Z:", sv(qc2).data)

qc3 = QuantumCircuit(1)
qc3.h(0)
qc3.z(0)
qc3.h(0)
print("Po H, Z, H:", sv(qc3).data)


print("Prawdopodobienstwa (H):", sv(qc1).probabilities_dict())
print("Prawdopodobienstwa (H,Z):", sv(qc2).probabilities_dict())
print("Prawdopodobienstwa (H,Z,H):", sv(qc3).probabilities_dict())
# Out:
# Po H: [0.70710678+0.j 0.70710678+0.j]
# Po H, Z: [ 0.70710678+0.j -0.70710678+0.j]
# Po H, Z, H: [-2.23711432e-17+0.j  1.00000000e+00+0.j]
# Prawdopodobienstwa (H): {np.str_('0'): np.float64(0.4999999999999999), np.str_('1'): np.float64(0.4999999999999999)}
# Prawdopodobienstwa (H,Z): {np.str_('0'): np.float64(0.4999999999999999), np.str_('1'): np.float64(0.4999999999999999)}
# Prawdopodobienstwa (H,Z,H): {np.str_('0'): np.float64(5.004680467665246e-34), np.str_('1'): np.float64(0.9999999999999996)}

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

qc = QuantumCircuit(2,2)
qc.h(0)
qc.cx(0,1)

qc.measure(0,0)
qc.measure(1,1)

sim=AerSimulator()
result=sim.run(qc, shots=2000).result()
result.get_counts()
# Out:
# {'11': 976, '00': 1024}
